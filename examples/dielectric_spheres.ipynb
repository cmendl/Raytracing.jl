# %% [markdown]
# # Dielectric spheres

# %%
using LinearAlgebra
using Images
using FileIO

# %%
include("../src/Raytracing.jl")
using .Raytracing

# %%
# image dimensions (pixel)
nx = 200
ny = 100;

# %%
# define camera
lookfrom = zeros(3)
lookat = [0., 0., -1.]
vup = [0., 1., 0.]
vfov = π/2
aperture = 0
focus_dist = 1
camera = Camera(lookfrom, lookat, vup, vfov, nx / ny, aperture, focus_dist);

# %%
# define scene geometry
scene = SurfaceAssembly([])
push!(scene.objects, Sphere([ 0., 0., -1.], 0.5, Lambertian([0.1, 0.2, 0.5])))
push!(scene.objects, Sphere([ 1., 0., -1.], 0.5, Metal([0.8, 0.6, 0.2], 1.0)))
# imitate hollow glass sphere
push!(scene.objects, Sphere([-1., 0., -1.],  0.5,  Dielectric(1.5)))
push!(scene.objects, Sphere([-1., 0., -1.], -0.45, Dielectric(1.5)))
# large "globe" sphere imitating ground floor
push!(scene.objects, Sphere([0., -100.5, -1.], 100., Lambertian([0.8, 0.8, 0.0])));

# %%
# number of samples (rays) per pixel
ns = 100

img = renderimage(nx, ny, ns, scene, camera)

# show rendered image
transpose(img)
# Out:
# 100×200 Array{RGB{Float32},2} with eltype RGB{Float32}:
#  RGB{Float32}(0.805241,0.888283,1.0)  …  RGB{Float32}(0.805248,0.888287,1.0)
#  RGB{Float32}(0.806364,0.888895,1.0)     RGB{Float32}(0.806355,0.88889,1.0)
#  RGB{Float32}(0.807408,0.889463,1.0)     RGB{Float32}(0.807425,0.889472,1.0)
#  RGB{Float32}(0.808483,0.890049,1.0)     RGB{Float32}(0.808465,0.890039,1.0)
#  RGB{Float32}(0.809581,0.890647,1.0)     RGB{Float32}(0.809571,0.890642,1.0)
#  RGB{Float32}(0.810732,0.891276,1.0)  …  RGB{Float32}(0.810693,0.891254,1.0)
#  RGB{Float32}(0.811827,0.891873,1.0)     RGB{Float32}(0.811781,0.891848,1.0)
#  RGB{Float32}(0.812965,0.892495,1.0)     RGB{Float32}(0.812959,0.892492,1.0)
#  RGB{Float32}(0.814066,0.893097,1.0)     RGB{Float32}(0.814089,0.89311,1.0)
#  RGB{Float32}(0.815174,0.893703,1.0)     RGB{Float32}(0.815191,0.893713,1.0)
#  RGB{Float32}(0.816215,0.894273,1.0)  …  RGB{Float32}(0.816281,0.894309,1.0)
# ...

# %%
# save to disk
save("dielectric_spheres.png", transpose(img))
